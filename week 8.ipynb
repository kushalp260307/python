# %%
#1
marks = [85, 72, 90, 60, 78]

print("Original marks:", marks)

marks.append(95)
print("After append(95):", marks)

marks.insert(2, 88)
print("After insert(2,88):", marks)

marks.remove(60)
print("After remove(60):", marks)

marks.sort()
print("After sort():", marks)
# Out:
# Original marks: [85, 72, 90, 60, 78]
# After append(95): [85, 72, 90, 60, 78, 95]
# After insert(2,88): [85, 72, 88, 90, 60, 78, 95]
# After remove(60): [85, 72, 88, 90, 78, 95]
# After sort(): [72, 78, 85, 88, 90, 95]

# %%
#2
cities = ("Mumbai", "Delhi", "Bengaluru", "Chennai")

print("First city :", cities[0])
print("Last city  :", cities[-1])
print("Length     :", len(cities))
print("Is Delhi present?", "Delhi" in cities)
# Out:
# First city : Mumbai
# Last city  : Chennai
# Length     : 4
# Is Delhi present? True

# %%
#3
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
print("Symmetric Difference:", A ^ B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 5, 6}

# %%
#4
student = {
    "name": "Rahul",
    "roll": 101,
    "marks": 75
}

print("Before update:", student)

student["marks"] = 89

print("After update:", student)
print("Keys:", student.keys())
print("Values:", student.values())
# Out:
# Before update: {'name': 'Rahul', 'roll': 101, 'marks': 75}
# After update: {'name': 'Rahul', 'roll': 101, 'marks': 89}
# Keys: dict_keys(['name', 'roll', 'marks'])
# Values: dict_values(['Rahul', 101, 89])

# %%
#5
items = ["Apple", "Milk", "Bread"]
prices = [50, 40, 35]

total = sum(prices)

for item, price in zip(items, prices):
    print(item, "₹", price)

print("Total Bill:", total)
# Out:
# Apple ₹ 50
# Milk ₹ 40
# Bread ₹ 35
# Total Bill: 125

# %%
#6
def addition(a, b):
    return a + b

def subtraction(a, b):
    return a - b

a = 10
b = 5

print("Addition:", addition(a, b))
print("Subtraction:", subtraction(a, b))
# Out:
# Addition: 15
# Subtraction: 5

# %%
#7
def check_even_odd(n):
    if n % 2 == 0:
        return "Even"
    else:
        return "Odd"

print(check_even_odd(7))
print(check_even_odd(12))
# Out:
# Odd
# Even

# %%
#8
def largest(a, b, c):
    return max(a, b, c)

print("Largest:", largest(10, 45, 30))
# Out:
# Largest: 45

# %%
#9
def factorial(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result

print("Factorial of 5:", factorial(5))
# Out:
# Factorial of 5: 120

# %%
#10
def is_prime(n):

    if n < 2:
        return False

    for i in range(2, n):
        if n % i == 0:
            return False

    return True

print(is_prime(7))
print(is_prime(10))
# Out:
# True
# False

# %%
#11
attendance = ["Alice", "Bob"]

attendance.append("Charlie")

print("Students:", attendance)

attendance.remove("Bob")

print("After removal:", attendance)
# Out:
# Students: ['Alice', 'Bob', 'Charlie']
# After removal: ['Alice', 'Charlie']

# %%
#12
employees = {
    "Amit": 45000,
    "Priya": 52000
}

employees["Amit"] = 50000

print(employees)
# Out:
# {'Amit': 50000, 'Priya': 52000}

# %%
#13
numbers = [1, 2, 2, 3, 4, 4, 5]

unique = set(numbers)

print("Unique numbers:", unique)
print("Count:", len(unique))
# Out:
# Unique numbers: {1, 2, 3, 4, 5}
# Count: 5

# %%
#14
def check_voting(age):

    if age >= 18:
        return "Eligible"

    return "Not Eligible"

print(check_voting(20))
print(check_voting(15))
# Out:
# Eligible
# Not Eligible

# %%
#15
sentence = "I love python python"

freq = {}

for word in sentence.split():
    freq[word] = freq.get(word, 0) + 1

print(freq)
# Out:
# {'I': 1, 'love': 1, 'python': 2}

# %%
#16
print("=" * 50)
print("Q16. Library Book System")
print("=" * 50)

library = ["Python Basics", "Data Structures", "Algorithms"]

def add_book(title):
    library.append(title)
    print(f"Book '{title}' added.")

def remove_book(title):
    if title in library:
        library.remove(title)
        print(f"Book '{title}' removed.")
    else:
        print(f"Book '{title}' not found.")

def search_book(title):
    if title in library:
        print(f"'{title}' is available.")
    else:
        print(f"'{title}' is not available.")

def display_books():
    print("Library books:", library)

add_book("Machine Learning")
remove_book("Algorithms")
search_book("Python Basics")
search_book("Java")
display_books()
# Out:
# ==================================================
# Q16. Library Book System
# ==================================================
# Book 'Machine Learning' added.
# Book 'Algorithms' removed.
# 'Python Basics' is available.
# 'Java' is not available.
# Library books: ['Python Basics', 'Data Structures', 'Machine Learning']

# %%
#17
print("=" * 50)
print("Q17. Student Result Analyzer")
print("=" * 50)

marks_list = [85, 38, 90, 72, 41]

def average(marks):
    return sum(marks) / len(marks)

def highest(marks):
    return max(marks)

def lowest(marks):
    return min(marks)

def passed(marks):
    return [m for m in marks if m > 40]

print("Marks   :", marks_list)
print("Average :", average(marks_list))
print("Highest :", highest(marks_list))
print("Lowest  :", lowest(marks_list))
print("Passed  :", passed(marks_list))
# Out:
# ==================================================
# Q17. Student Result Analyzer
# ==================================================
# Marks   : [85, 38, 90, 72, 41]
# Average : 65.2
# Highest : 90
# Lowest  : 38
# Passed  : [85, 90, 72, 41]

# %%
#18
print("=" * 50)
print("Q18. Password Strength Checker")
print("=" * 50)

def check_password_strength(password):

    checks = {
        "Min length 8": len(password) >= 8,
        "Has digit": any(c.isdigit() for c in password),
        "Has uppercase": any(c.isupper() for c in password),
        "Has lowercase": any(c.islower() for c in password),
    }

    print("Password:", password)

    for check, result in checks.items():
        print(check, ":", result)

    if all(checks.values()):
        print("STRONG PASSWORD")
    else:
        print("WEAK PASSWORD")

check_password_strength("hello")
check_password_strength("Hello@123")
# Out:
# ==================================================
# Q18. Password Strength Checker
# ==================================================
# Password: hello
# Min length 8 : False
# Has digit : False
# Has uppercase : False
# Has lowercase : True
# WEAK PASSWORD
# Password: Hello@123
# Min length 8 : True
# Has digit : True
# Has uppercase : True
# Has lowercase : True
# STRONG PASSWORD

# %%
#19
print("=" * 50)
print("Q19. Contact Book Application")
print("=" * 50)

contacts = {
    "Aman": "9876543210",
    "Pooja": "9123456780"
}

def add_contact(name, number):
    contacts[name] = number
    print(f"Contact '{name}' added.")

def search_contact(name):
    if name in contacts:
        print(name, ":", contacts[name])
    else:
        print("Contact not found.")

def delete_contact(name):
    if name in contacts:
        del contacts[name]
        print(f"'{name}' deleted.")
    else:
        print("Contact not found.")

def display_contacts():
    print("All Contacts:", contacts)

add_contact("Raj", "9000012345")
search_contact("Pooja")
delete_contact("Aman")
display_contacts()
# Out:
# ==================================================
# Q19. Contact Book Application
# ==================================================
# Contact 'Raj' added.
# Pooja : 9123456780
# 'Aman' deleted.
# All Contacts: {'Pooja': '9123456780', 'Raj': '9000012345'}

# %%
#20
print("=" * 50)
print("Q20. Mini Banking System")
print("=" * 50)

balance = 5000

def deposit(amount):
    global balance
    balance += amount
    print("Deposited:", amount)

def withdraw(amount):
    global balance

    if amount > balance:
        print("Insufficient balance!")

    else:
        balance -= amount
        print("Withdrawn:", amount)

def check_balance():
    print("Current Balance:", balance)

check_balance()
deposit(2000)
withdraw(1500)
withdraw(10000)
check_balance()
# Out:
# ==================================================
# Q20. Mini Banking System
# ==================================================
# Current Balance: 5000
# Deposited: 2000
# Withdrawn: 1500
# Insufficient balance!
# Current Balance: 5500

# %%
#21
print("=" * 50)
print("Q21. HackerRank Style")
print("=" * 50)

nums = [10, 20, 30, 40, 50]

print("Original list:", nums)

maximum = nums[0]

for n in nums:
    if n > maximum:
        maximum = n

print("Maximum:", maximum)

minimum = nums[0]

for n in nums:
    if n < minimum:
       minimum = n

print("Minimum:", minimum)

reversed_list = []

for i in range(len(nums)-1, -1, -1):
    reversed_list.append(nums[i])

print("Reversed list:", reversed_list)
# Out:
# ==================================================
# Q21. HackerRank Style
# ==================================================
# Original list: [10, 20, 30, 40, 50]
# Maximum: 50
# Minimum: 10
# Reversed list: [50, 40, 30, 20, 10]
